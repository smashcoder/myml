# %% [markdown]
# <a href="https://colab.research.google.com/github/smashcoder/myml/blob/main/INTERNET_PRICE_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pn
data = pn.read_csv('/content/worldwide internet prices in 2022 - IN 2022.csv')
print (data)
# Out:
#     Country code                            Name  Continental region  \
# 0             IL                          Israel           NEAR EAST
# 1             KG                      Kyrgyzstan   CIS (FORMER USSR)
# 2             FJ                            Fiji             OCEANIA
# 3             IT                           Italy      WESTERN EUROPE
# 4             SD                           Sudan  SUB-SAHARAN AFRICA
# ..           ...                             ...                 ...
# 237           VA         Vatican City (Holy See)              Europe
# 238           VE                       Venezuela       SOUTH AMERICA
# 239           WF               Wallis and Futuna             OCEANIA
# 240           CD  Congo (Democratic Republic of)  SUB-SAHARAN AFRICA
# 241           ZW                        Zimbabwe  SUB-SAHARAN AFRICA
#
#      NO OF Internet Plans                       Average price of 1GB  \
# ...

# %%
import pandas as pn
data = pn.read_csv('/content/worldwide internet prices in 2022 - IN 2022.csv')
data.head()
# Out:
#   Country code        Name  Continental region  NO OF Internet Plans   \
# 0           IL      Israel           NEAR EAST                   27.0
# 1           KG  Kyrgyzstan   CIS (FORMER USSR)                   20.0
# 2           FJ        Fiji             OCEANIA                   18.0
# 3           IT       Italy      WESTERN EUROPE                   29.0
# 4           SD       Sudan  SUB-SAHARAN AFRICA                   33.0
#
#   Average price of 1GB  Cheapest 1GB for 30 days  Most expensive 1GB (USD)  \
# 0                 0.05                      0.02                     20.95
# 1                 0.15                      0.10                      7.08
# 2                 0.19                      0.05                      0.85
# 3                 0.27                      0.09                      3.54
# 4                 0.27                      0.03                      0.92
#
#   Average price of 1GB (USD  at the start of 2021)  \
# ...

# %%
import pandas as pn
data = pn.read_csv('/content/worldwide internet prices in 2022 - IN 2022.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 9 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Country code                                      241 non-null    object
#  1   Name                                              242 non-null    object
#  2   Continental region                                242 non-null    object
#  3   NO OF Internet Plans                              230 non-null    float64
#  4   Average price of 1GB                              242 non-null    object
#  5   Cheapest 1GB for 30 days                          230 non-null    float64
#  6   Most expensive 1GB (USD)                          230 non-null    float64
#  7   Average price of 1GB (USD  at the start of 2021)  230 non-null    object
#  8   Average price of 1GB (USD at start of 2020)       230 non-null    object
# ...

# %%
import matplotlib.pyplot as plt
data.plot(x='Cheapest 1GB for 30 days', y='Most expensive 1GB (USD)', style='o')
plt.show()

# %%
data.corr()
# Out:
#                           NO OF Internet Plans   Cheapest 1GB for 30 days  \
# NO OF Internet Plans                   1.000000                 -0.301301
# Cheapest 1GB for 30 days              -0.301301                  1.000000
# Most expensive 1GB (USD)              -0.050625                  0.085185
#
#                           Most expensive 1GB (USD)
# NO OF Internet Plans                     -0.050625
# Cheapest 1GB for 30 days                  0.085185
# Most expensive 1GB (USD)                  1.000000

# %%
data.describe()
# Out:
#        NO OF Internet Plans   Cheapest 1GB for 30 days  \
# count             230.000000                230.000000
# mean               26.730435                  1.722652
# std                16.468216                  4.774479
# min                 1.000000                  0.000000
# 25%                15.000000                  0.212500
# 50%                22.000000                  0.630000
# 75%                36.000000                  1.390000
# max                60.000000                 45.160000
#
#        Most expensive 1GB (USD)
# count                230.000000
# mean                  29.730348
# std                   59.329737
# min                    0.630000
# 25%                    5.902500
# 50%                   12.525000
# 75%                   34.295000
# max                  768.870000
